# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
df = pd.read_csv('data/epa-sea-level.csv')

# %%
df.describe()
# Out:
#               Year  CSIRO Adjusted Sea Level  Lower Error Bound  \
# count   134.000000                134.000000         134.000000
# mean   1946.500000                  3.650341           3.204666
# std      38.826537                  2.485692           2.663781
# min    1880.000000                 -0.440945          -1.346457
# 25%    1913.250000                  1.632874           1.078740
# 50%    1946.500000                  3.312992           2.915354
# 75%    1979.750000                  5.587598           5.329724
# max    2013.000000                  9.326772           8.992126
#
#        Upper Error Bound  NOAA Adjusted Sea Level
# count         134.000000                21.000000
# mean            4.096016                 7.363746
# std             2.312581                 0.691038
# min             0.464567                 6.297493
# 25%             2.240157                 6.848690
# 50%             3.710630                 7.488353
# 75%             5.845472                 7.907365
# max             9.661417                 8.546648

# %%
res1 = linregress(df['Year'], df['CSIRO Adjusted Sea Level'])

# %%
df2 = df[df['Year']>=2000]

# %%
res2 = linregress(df2['Year'], df2['CSIRO Adjusted Sea Level'])

# %%
added_years = pd.DataFrame(np.arange(2014, 2051, 1), columns=['Year'])

# %%
df1 = pd.concat([df, added_years])

# %%
df1.head()
# Out:
#    Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880                  0.000000          -0.952756           0.952756
# 1  1881                  0.220472          -0.732283           1.173228
# 2  1882                 -0.440945          -1.346457           0.464567
# 3  1883                 -0.232283          -1.129921           0.665354
# 4  1884                  0.590551          -0.283465           1.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
df1.tail()
# Out:
#     Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 32  2046                       NaN                NaN                NaN
# 33  2047                       NaN                NaN                NaN
# 34  2048                       NaN                NaN                NaN
# 35  2049                       NaN                NaN                NaN
# 36  2050                       NaN                NaN                NaN
#
#     NOAA Adjusted Sea Level
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN

# %%
df1.describe()
# Out:
#               Year  CSIRO Adjusted Sea Level  Lower Error Bound  \
# count   171.000000                134.000000         134.000000
# mean   1965.000000                  3.650341           3.204666
# std      49.507575                  2.485692           2.663781
# min    1880.000000                 -0.440945          -1.346457
# 25%    1922.500000                  1.632874           1.078740
# 50%    1965.000000                  3.312992           2.915354
# 75%    2007.500000                  5.587598           5.329724
# max    2050.000000                  9.326772           8.992126
#
#        Upper Error Bound  NOAA Adjusted Sea Level
# count         134.000000                21.000000
# mean            4.096016                 7.363746
# std             2.312581                 0.691038
# min             0.464567                 6.297493
# 25%             2.240157                 6.848690
# 50%             3.710630                 7.488353
# 75%             5.845472                 7.907365
# max             9.661417                 8.546648

# %%
df2 = pd.concat([df2, added_years])

# %%
df2.head()
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 120  2000                  7.062992           6.791339           7.334646
# 121  2001                  7.287402           7.019685           7.555118
# 122  2002                  7.381890           7.110236           7.653543
# 123  2003                  7.759843           7.484252           8.035433
# 124  2004                  7.740157           7.464567           8.015748
#
#      NOAA Adjusted Sea Level
# 120                 6.920582
# 121                 7.087460
# 122                 7.319698
# 123                 7.488353
# 124                 7.507933

# %%
df2.tail()
# Out:
#     Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 32  2046                       NaN                NaN                NaN
# 33  2047                       NaN                NaN                NaN
# 34  2048                       NaN                NaN                NaN
# 35  2049                       NaN                NaN                NaN
# 36  2050                       NaN                NaN                NaN
#
#     NOAA Adjusted Sea Level
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN

# %%
df2.describe()
# Out:
#               Year  CSIRO Adjusted Sea Level  Lower Error Bound  \
# count    51.000000                 14.000000          14.000000
# mean   2025.000000                  8.142857           7.856018
# std      14.866069                  0.713125           0.693719
# min    2000.000000                  7.062992           6.791339
# 25%    2012.500000                  7.741142           7.466535
# 50%    2025.000000                  7.956693           7.679134
# 75%    2037.500000                  8.822835           8.541339
# max    2050.000000                  9.326772           8.992126
#
#        Upper Error Bound  NOAA Adjusted Sea Level
# count          14.000000                14.000000
# mean            8.429696                 7.750116
# std             0.733022                 0.475023
# min             7.334646                 6.920582
# 25%             8.015748                 7.493248
# 50%             8.234252                 7.699784
# 75%             9.104331                 8.051387
# max             9.661417                 8.546648

# %%
fig = plt.scatter(df['Year'], df['CSIRO Adjusted Sea Level'], marker='.')
plt.title('Rise in Sea Level')
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.plot(df1['Year'], res1.intercept + res1.slope*df1['Year'], 'r', label='fitted line since 1880')
plt.plot(df2['Year'], res2.intercept + res2.slope*df2['Year'], '--b', label='fitted line since 2000')
plt.legend()

# %%
print(res1.intercept, res1.slope)
# Out:
# -119.06594196773983 0.06304458401213482

# %%
print(res2.intercept, res2.slope)
# Out:
# -325.7934668059649 0.1664272733318682
